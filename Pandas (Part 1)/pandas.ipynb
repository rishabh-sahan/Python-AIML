# %%
import pandas as pd

# %%
info = {
    "Name" : ["Rishabh", "Sahan", "Abhi"],
    "CGPA" :  [9.5, 7.5, 8.5]
}

df = pd.DataFrame(info)
print(df)
# Out:
#       Name  CGPA
# 0  Rishabh   9.5
# 1    Sahan   7.5
# 2     Abhi   8.5

# %%
df
# Out:
#       Name  CGPA
# 0  Rishabh   9.5
# 1    Sahan   7.5
# 2     Abhi   8.5

# %%
s = pd.Series([1, 2, 3, 4, 5])
print(s)
